# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# Introduction
# In this report, we will explore the insights and visualizations derived from the wrangled data of the WeRateDogs Twitter account. The data was gathered, assessed, and cleaned to ensure its quality and tidiness. Now, let's dive into the findings and visualizations that provide interesting insights into the WeRateDogs Twitter data.
#
# Insights
# Popular Dog Breeds: After analyzing the cleaned data, we found that the most popular dog breeds based on the number of tweets were Labrador Retrievers, Golden Retrievers, and Pembroke Welsh Corgis. These breeds consistently received high ratings and garnered a significant number of retweets and favorites.
#
# Relationship between Ratings and Popularity: We discovered a positive correlation between the ratings given to dogs and their popularity on Twitter. Dogs with higher ratings tended to receive more retweets and favorites, indicating a higher level of engagement from the audience.
#
# Time of Day and Dog Engagement: Analyzing the timestamp data, we observed that the engagement levels for dog tweets varied throughout the day. Tweets posted during the late evening and early morning hours received higher retweet and favorite counts compared to tweets posted during the rest of the day.
#
# Conclusion
# The analysis of the WeRateDogs Twitter data has provided valuable insights into popular dog breeds, the relationship between ratings and popularity, and the impact of timing on engagement levels. These findings demonstrate the strong connection between engaging dog content and the Twitter audience. By understanding these patterns, we can better comprehend the preferences and behaviors of dog-loving Twitter users.

# %% [markdown]
# ![download.png](attachment:download.png)![download.jpg](attachment:download.jpg)

# %% [markdown]
# Visualization The top 10 predicted dog breeds are important because they provide valuable insights into the classification of dog images based on machine learning algorithms. These predicted breeds can be used to analyze and understand the composition of the dog images in the dataset.
#
# Breed Identification: By identifying the top predicted dog breeds, we can gain insights into the distribution and prevalence of different breeds in the dataset. This information can be useful for understanding the popularity of certain breeds or for studying specific breed characteristics.
#
# Accuracy Assessment: The top predicted dog breeds can be compared to the actual dog breeds in the dataset to assess the accuracy of the image classification model. If the predicted breeds align closely with the actual breeds, it indicates a higher level of accuracy and reliability in the machine learning algorithm.
#
# Data Quality Check: Analyzing the top predicted dog breeds can help identify potential data quality issues. For example, if certain breeds consistently appear in the top predictions but are not represented in the actual dog breed labels, it may indicate mislabeled data or errors in the dataset.
#
# Insights into Dog Image Characteristics: Different dog breeds have distinct physical features and characteristics. By examining the top predicted dog breeds, we can gain insights into the visual attributes that the machine learning algorithm uses to differentiate and classify dog images. This information can be valuable for further understanding the algorithm's decision-making process.
#
# Comparative Analysis: The top predicted dog breeds can be compared across different datasets or time periods to observe any changes in breed popularity or image classification trends. This comparative analysis can provide insights into evolving preferences or trends in dog breeds.
